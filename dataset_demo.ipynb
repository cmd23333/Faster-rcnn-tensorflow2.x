# %%
from utils.data import *

# %%
# %matplotlib notebook

# %%
config.voc_data_dir = 'D:/DataClinic/simple-faster-rcnn-pytorch/VOCdevkit/VOC2007/'

# %%
dataset = Dataset(config)

# %%
img, bboxes, labels, scale = dataset[1]

print(img.shape, 'max=', tf.reduce_max(img).numpy(), 'min=', tf.reduce_min(img).numpy())
print(bboxes.shape, 'max=', tf.reduce_max(bboxes).numpy())
print(labels.shape)
# Out:
# (600, 900, 3) max= 2.64 min= -2.117904
# (1, 4) max= 898.19995
# (1,)

# %%
bboxes
# Out:
# array([[ 88.28829, 252.     , 592.7928 , 898.19995]], dtype=float32)

# %%
labels
# Out:
# array([6])

# %%
tf.reduce_mean(img)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.44019473>

# %%
vis(img, bboxes, labels)
# Out:
# <img src="data:image/png;base64,..." width="640">
# WARNING: Logging before flag parsing goes to stderr.
# W0630 23:09:16.472195 10956 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
